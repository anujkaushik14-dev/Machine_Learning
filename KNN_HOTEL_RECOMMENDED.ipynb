# %% [markdown]
# # KNN_HOTEL_RECOMMENDED

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\vv\Downloads\Telegram Desktop\Hotel_Reviews.csv")
df
# Out:
#                                             Hotel_Address  \
# 0        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 1        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 2        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 3        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 4        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# ...                                                   ...
# 515733  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515734  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515735  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515736  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515737  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
#
#         Additional_Number_of_Scoring Review_Date  Average_Score  \
# 0                                194    8/3/2017            7.7
# 1                                194    8/3/2017            7.7
# 2                                194   7/31/2017            7.7
# ...

# %%
df.isnull().sum()
# Out:
# Hotel_Address                                    0
# Additional_Number_of_Scoring                     0
# Review_Date                                      0
# Average_Score                                    0
# Hotel_Name                                       0
# Reviewer_Nationality                             0
# Negative_Review                                  0
# Review_Total_Negative_Word_Counts                0
# Total_Number_of_Reviews                          0
# Positive_Review                                  0
# Review_Total_Positive_Word_Counts                0
# Total_Number_of_Reviews_Reviewer_Has_Given       0
# Reviewer_Score                                   0
# Tags                                             0
# days_since_review                                0
# lat                                           3268
# lng                                           3268
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
colm='Reviewer_Nationality'
encoder=LabelEncoder()
df[colm]=encoder.fit_transform(df[colm])


# from sklearn.preprocessing import LabelEncoder
# colm=['roomamenities','ratedescription']
# le=LabelEncoder()
# for col in colm:
#     df[col]=le.fit_transform(df[col])

# from sklearn.preprocessing import LabelEncoder
# colm=['roomamenities','ratedescription']
# encoders=[]
# for colm in col:
#     le=LabelEncoder()
#     df[col]= le.fit_transform(df[col])
#     encoders.append(le)

# from sklearn.preprocessing import OrdinalEncoder
# colm=['roomamenities','ratedescription']
# encoder=OrdinalEncoder()
# df[colm]=encoder.fit(transform(df[colm])

# %%
df['lat'] = df['lat'].fillna(df['lat'].median())
df
# Out:
#                                             Hotel_Address  \
# 0        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 1        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 2        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 3        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 4        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# ...                                                   ...
# 515733  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515734  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515735  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515736  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515737  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
#
#         Additional_Number_of_Scoring Review_Date  Average_Score  \
# 0                                194    8/3/2017            7.7
# 1                                194    8/3/2017            7.7
# 2                                194   7/31/2017            7.7
# ...

# %%
df['lng'] = df['lng'].fillna(df['lng'].median())
df
# Out:
#                                             Hotel_Address  \
# 0        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 1        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 2        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 3        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 4        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# ...                                                   ...
# 515733  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515734  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515735  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515736  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515737  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
#
#         Additional_Number_of_Scoring Review_Date  Average_Score  \
# 0                                194    8/3/2017            7.7
# 1                                194    8/3/2017            7.7
# 2                                194   7/31/2017            7.7
# ...

# %%
import numpy as np

# %%
df.isnull().sum()
# Out:
# Hotel_Address                                 0
# Additional_Number_of_Scoring                  0
# Review_Date                                   0
# Average_Score                                 0
# Hotel_Name                                    0
# Reviewer_Nationality                          0
# Negative_Review                               0
# Review_Total_Negative_Word_Counts             0
# Total_Number_of_Reviews                       0
# Positive_Review                               0
# Review_Total_Positive_Word_Counts             0
# Total_Number_of_Reviews_Reviewer_Has_Given    0
# Reviewer_Score                                0
# Tags                                          0
# days_since_review                             0
# lat                                           0
# lng                                           0
# dtype: int64

# %%
x=df[['Additional_Number_of_Scoring','Average_Score','Reviewer_Nationality','Reviewer_Score']]
y=df['Hotel_Name']

x
# Out:
#         Additional_Number_of_Scoring  Average_Score  Reviewer_Nationality  \
# 0                                194            7.7                   167
# 1                                194            7.7                    98
# 2                                194            7.7                    14
# 3                                194            7.7                   214
# 4                                194            7.7                   146
# ...                              ...            ...                   ...
# 515733                           168            8.1                   111
# 515734                           168            8.1                    66
# 515735                           168            8.1                    62
# 515736                           168            8.1                   133
# 515737                           168            8.1                    92
#
#         Reviewer_Score
# 0                  2.9
# 1                  7.5
# ...

# %%
y
# Out:
# 0                   Hotel Arena
# 1                   Hotel Arena
# 2                   Hotel Arena
# 3                   Hotel Arena
# 4                   Hotel Arena
#                   ...
# 515733    Atlantis Hotel Vienna
# 515734    Atlantis Hotel Vienna
# 515735    Atlantis Hotel Vienna
# 515736    Atlantis Hotel Vienna
# 515737    Atlantis Hotel Vienna
# Name: Hotel_Name, Length: 515738, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=0)

y_test
# Out:
# 276954                               Novotel Barcelona City
# 231304                    Radisson Blu Edwardian Vanderbilt
# 247559                Mercure Paris Gobelins Place d Italie
# 432314                              Negresco Princess 4 Sup
# 453374                      Austria Trend Hotel Ananas Wien
#                                 ...
# 237933    DoubleTree by Hilton Hotel London Tower of London
# 401290                                    K K Hotel Picasso
# 402865                              Catalonia Ramblas 4 Sup
# 52949                              Hilton London Paddington
# 443464               Copthorne Tara Hotel London Kensington
# Name: Hotel_Name, Length: 51574, dtype: object

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=1)

knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
pred=knn.predict(x_test)
pred
# Out:
# array(['Novotel Barcelona City', 'Radisson Blu Edwardian Vanderbilt',
#        'Mercure Paris Gobelins Place d Italie', ...,
#        'Catalonia Ramblas 4 Sup', 'Hilton London Paddington',
#        'Copthorne Tara Hotel London Kensington'],
#       shape=(51574,), dtype=object)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

results=confusion_matrix(y_test,pred)
print('confusion matrix')
print(results)
print('Accuracy score:', accuracy_score(y_test, pred))
print(classification_report(y_test, pred))
# Out:
# confusion matrix
# [[  6   0   0 ...   0   0   0]
#  [  0   5   0 ...   0   0   0]
#  [  0   0  32 ...   0   0   0]
#  ...
#  [  0   0   0 ... 174   0   0]
#  [  0   0   0 ...   0  57   0]
#  [  0   0   0 ...   0   0   4]]
# Accuracy score: 0.8411021057121806
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
import numpy as np

# %%
k=np.array([[168,8.1,92,8.3]])
k
# Out:
# array([[168. ,   8.1,  92. ,   8.3]])

# %%
pred=knn.predict(k)
pred
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array(['Atlantis Hotel Vienna'], dtype=object)

# %%
df3=pd.read_csv(r"C:\Users\vv\OneDrive\Desktop\PYTHON\personalized_medication_dataset.csv")
df3
# Out:
#     Patient_ID  Age  Gender  Weight_kg  Height_cm   BMI Chronic_Conditions  \
# 0        P0001   78   Other       88.7      196.3  21.1                NaN
# 1        P0002   57  Female       90.5      195.6  30.2       Hypertension
# 2        P0003   29  Female       87.0      168.2  27.0                NaN
# 3        P0004   56  Female       81.4      188.9  26.9       Hypertension
# 4        P0005   90    Male       64.2      157.0  33.3                NaN
# ..         ...  ...     ...        ...        ...   ...                ...
# 995      P0996   37    Male       99.1      159.2  26.8           Diabetes
# 996      P0997   28   Other      102.8      178.7  34.1             Asthma
# 997      P0998   67    Male       58.1      198.1  20.4             Asthma
# 998      P0999   79    Male       51.1      171.9  25.8       Hypertension
# 999      P1000   70   Other       62.4      199.8  25.4             Asthma
#
#     Drug_Allergies   Genetic_Disorders     Diagnosis  \
# ...

# %%
df3 = df3.map(lambda x: x.strip() if isinstance(x, str) else x)

# %%
df3.isnull().sum()
# Out:
# Patient_ID                   0
# Age                          0
# Gender                       0
# Weight_kg                    0
# Height_cm                    0
# BMI                          0
# Chronic_Conditions         246
# Drug_Allergies             324
# Genetic_Disorders          339
# Diagnosis                    0
# Symptoms                     0
# Recommended_Medication     263
# Dosage                     195
# Duration                   257
# Treatment_Effectiveness      0
# Adverse_Reactions            0
# Recovery_Time_Days           0
# dtype: int64

# %%
df3.plot.box()
# Out:
# <Axes: >

# %%
df3['Chronic_Conditions'].fillna(method='bfill',inplace=True)
df3
# Out:
# C:\Users\vv\AppData\Local\Temp\ipykernel_9584\2633287253.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df3['Chronic_Conditions'].fillna(method='bfill',inplace=True)
# C:\Users\vv\AppData\Local\Temp\ipykernel_9584\2633287253.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3['Chronic_Conditions'].fillna(method='bfill',inplace=True)
#     Patient_ID  Age  Gender  Weight_kg  Height_cm   BMI Chronic_Conditions  \
# ...

# %%
df3.isnull().sum()
# Out:
# Patient_ID                   0
# Age                          0
# Gender                       0
# Weight_kg                    0
# Height_cm                    0
# BMI                          0
# Chronic_Conditions           0
# Drug_Allergies             324
# Genetic_Disorders          339
# Diagnosis                    0
# Symptoms                     0
# Recommended_Medication     263
# Dosage                     195
# Duration                   257
# Treatment_Effectiveness      0
# Adverse_Reactions            0
# Recovery_Time_Days           0
# dtype: int64

# %%
df3['Drug_Allergies'].fillna(method='ffill',inplace=True)
df3
# Out:
# C:\Users\vv\AppData\Local\Temp\ipykernel_9584\249213628.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df3['Drug_Allergies'].fillna(method='ffill',inplace=True)
# C:\Users\vv\AppData\Local\Temp\ipykernel_9584\249213628.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3['Drug_Allergies'].fillna(method='ffill',inplace=True)
#     Patient_ID  Age  Gender  Weight_kg  Height_cm   BMI Chronic_Conditions  \
# ...

# %%
df3.isnull().sum()
# Out:
# Patient_ID                   0
# Age                          0
# Gender                       0
# Weight_kg                    0
# Height_cm                    0
# BMI                          0
# Chronic_Conditions           0
# Drug_Allergies               0
# Genetic_Disorders          339
# Diagnosis                    0
# Symptoms                     0
# Recommended_Medication     263
# Dosage                     195
# Duration                   257
# Treatment_Effectiveness      0
# Adverse_Reactions            0
# Recovery_Time_Days           0
# dtype: int64

# %%
df3['Genetic_Disorders'].fillna(method='ffill',inplace=True)
df3
# Out:
# C:\Users\vv\AppData\Local\Temp\ipykernel_9584\231276978.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df3['Genetic_Disorders'].fillna(method='ffill',inplace=True)
# C:\Users\vv\AppData\Local\Temp\ipykernel_9584\231276978.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3['Genetic_Disorders'].fillna(method='ffill',inplace=True)
#     Patient_ID  Age  Gender  Weight_kg  Height_cm   BMI Chronic_Conditions  \
# ...

# %%
df3.isnull().sum()
# Out:
# Patient_ID                   0
# Age                          0
# Gender                       0
# Weight_kg                    0
# Height_cm                    0
# BMI                          0
# Chronic_Conditions           0
# Drug_Allergies               0
# Genetic_Disorders            0
# Diagnosis                    0
# Symptoms                     0
# Recommended_Medication     263
# Dosage                     195
# Duration                   257
# Treatment_Effectiveness      0
# Adverse_Reactions            0
# Recovery_Time_Days           0
# dtype: int64

# %%
df3['Recommended_Medication'].fillna(method='ffill',inplace=True)
df3
# Out:
# C:\Users\vv\AppData\Local\Temp\ipykernel_9584\3613720687.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df3['Recommended_Medication'].fillna(method='ffill',inplace=True)
# C:\Users\vv\AppData\Local\Temp\ipykernel_9584\3613720687.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3['Recommended_Medication'].fillna(method='ffill',inplace=True)
# ...

# %%
df3.isnull().sum()
# Out:
# Patient_ID                   0
# Age                          0
# Gender                       0
# Weight_kg                    0
# Height_cm                    0
# BMI                          0
# Chronic_Conditions           0
# Drug_Allergies               0
# Genetic_Disorders            0
# Diagnosis                    0
# Symptoms                     0
# Recommended_Medication       0
# Dosage                     195
# Duration                   257
# Treatment_Effectiveness      0
# Adverse_Reactions            0
# Recovery_Time_Days           0
# dtype: int64

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Patient_ID               1000 non-null   object
#  1   Age                      1000 non-null   int64
#  2   Gender                   1000 non-null   object
#  3   Weight_kg                1000 non-null   float64
#  4   Height_cm                1000 non-null   float64
#  5   BMI                      1000 non-null   float64
#  6   Chronic_Conditions       1000 non-null   object
#  7   Drug_Allergies           1000 non-null   object
#  8   Genetic_Disorders        1000 non-null   object
#  9   Diagnosis                1000 non-null   object
#  10  Symptoms                 1000 non-null   object
#  11  Recommended_Medication   1000 non-null   object
#  12  Dosage                   805 non-null    object
#  13  Duration                 743 non-null    object
# ...

# %%
df3['Dosage'] = df3['Dosage'].str.replace(r'mg', '', regex=True).str.strip()
df3['Dosage'] = pd.to_numeric(df3['Dosage'])
df3
# Out:
#     Patient_ID  Age  Gender  Weight_kg  Height_cm   BMI Chronic_Conditions  \
# 0        P0001   78   Other       88.7      196.3  21.1       Hypertension
# 1        P0002   57  Female       90.5      195.6  30.2       Hypertension
# 2        P0003   29  Female       87.0      168.2  27.0       Hypertension
# 3        P0004   56  Female       81.4      188.9  26.9       Hypertension
# 4        P0005   90    Male       64.2      157.0  33.3       Hypertension
# ..         ...  ...     ...        ...        ...   ...                ...
# 995      P0996   37    Male       99.1      159.2  26.8           Diabetes
# 996      P0997   28   Other      102.8      178.7  34.1             Asthma
# 997      P0998   67    Male       58.1      198.1  20.4             Asthma
# 998      P0999   79    Male       51.1      171.9  25.8       Hypertension
# 999      P1000   70   Other       62.4      199.8  25.4             Asthma
#
#     Drug_Allergies   Genetic_Disorders     Diagnosis  \
# ...

# %%
random_filler = pd.Series(np.random.randint(200, 500, size=len(df3)))
df3['Dosage'] = df3['Dosage'].fillna(random_filler)
df3
# Out:
#     Patient_ID  Age  Gender  Weight_kg  Height_cm   BMI Chronic_Conditions  \
# 0        P0001   78   Other       88.7      196.3  21.1       Hypertension
# 1        P0002   57  Female       90.5      195.6  30.2       Hypertension
# 2        P0003   29  Female       87.0      168.2  27.0       Hypertension
# 3        P0004   56  Female       81.4      188.9  26.9       Hypertension
# 4        P0005   90    Male       64.2      157.0  33.3       Hypertension
# ..         ...  ...     ...        ...        ...   ...                ...
# 995      P0996   37    Male       99.1      159.2  26.8           Diabetes
# 996      P0997   28   Other      102.8      178.7  34.1             Asthma
# 997      P0998   67    Male       58.1      198.1  20.4             Asthma
# 998      P0999   79    Male       51.1      171.9  25.8       Hypertension
# 999      P1000   70   Other       62.4      199.8  25.4             Asthma
#
#     Drug_Allergies   Genetic_Disorders     Diagnosis  \
# ...

# %%
df3.isnull().sum()
# Out:
# Patient_ID                   0
# Age                          0
# Gender                       0
# Weight_kg                    0
# Height_cm                    0
# BMI                          0
# Chronic_Conditions           0
# Drug_Allergies               0
# Genetic_Disorders            0
# Diagnosis                    0
# Symptoms                     0
# Recommended_Medication       0
# Dosage                       0
# Duration                   257
# Treatment_Effectiveness      0
# Adverse_Reactions            0
# Recovery_Time_Days           0
# dtype: int64

# %%
df3['Duration'] = df3['Duration'].str.replace(r'days', '', regex=True).str.strip()
df3['Duration'] = pd.to_numeric(df3['Duration'])
df3
# Out:
#     Patient_ID  Age  Gender  Weight_kg  Height_cm   BMI Chronic_Conditions  \
# 0        P0001   78   Other       88.7      196.3  21.1       Hypertension
# 1        P0002   57  Female       90.5      195.6  30.2       Hypertension
# 2        P0003   29  Female       87.0      168.2  27.0       Hypertension
# 3        P0004   56  Female       81.4      188.9  26.9       Hypertension
# 4        P0005   90    Male       64.2      157.0  33.3       Hypertension
# ..         ...  ...     ...        ...        ...   ...                ...
# 995      P0996   37    Male       99.1      159.2  26.8           Diabetes
# 996      P0997   28   Other      102.8      178.7  34.1             Asthma
# 997      P0998   67    Male       58.1      198.1  20.4             Asthma
# 998      P0999   79    Male       51.1      171.9  25.8       Hypertension
# 999      P1000   70   Other       62.4      199.8  25.4             Asthma
#
#     Drug_Allergies   Genetic_Disorders     Diagnosis  \
# ...

# %%
random_filler = pd.Series(np.random.randint(5, 30, size=len(df3)))
df3['Duration'] = df3['Duration'].fillna(random_filler)
df3
# Out:
#     Patient_ID  Age  Gender  Weight_kg  Height_cm   BMI Chronic_Conditions  \
# 0        P0001   78   Other       88.7      196.3  21.1       Hypertension
# 1        P0002   57  Female       90.5      195.6  30.2       Hypertension
# 2        P0003   29  Female       87.0      168.2  27.0       Hypertension
# 3        P0004   56  Female       81.4      188.9  26.9       Hypertension
# 4        P0005   90    Male       64.2      157.0  33.3       Hypertension
# ..         ...  ...     ...        ...        ...   ...                ...
# 995      P0996   37    Male       99.1      159.2  26.8           Diabetes
# 996      P0997   28   Other      102.8      178.7  34.1             Asthma
# 997      P0998   67    Male       58.1      198.1  20.4             Asthma
# 998      P0999   79    Male       51.1      171.9  25.8       Hypertension
# 999      P1000   70   Other       62.4      199.8  25.4             Asthma
#
#     Drug_Allergies   Genetic_Disorders     Diagnosis  \
# ...

# %%
# df3['Duration'] = pd.to_numeric(df3['Duration'].astype(str).str.replace(r'\s*days', '', regex=True), errors='coerce').fillna(median_duration).astype('int64')
# df3

# %%
df3.isnull().sum()
# Out:
# Patient_ID                 0
# Age                        0
# Gender                     0
# Weight_kg                  0
# Height_cm                  0
# BMI                        0
# Chronic_Conditions         0
# Drug_Allergies             0
# Genetic_Disorders          0
# Diagnosis                  0
# Symptoms                   0
# Recommended_Medication     0
# Dosage                     0
# Duration                   0
# Treatment_Effectiveness    0
# Adverse_Reactions          0
# Recovery_Time_Days         0
# dtype: int64

# %%
df3.isnull().sum()
# Out:
# Patient_ID                 0
# Age                        0
# Gender                     0
# Weight_kg                  0
# Height_cm                  0
# BMI                        0
# Chronic_Conditions         0
# Drug_Allergies             0
# Genetic_Disorders          0
# Diagnosis                  0
# Symptoms                   0
# Recommended_Medication     0
# Dosage                     0
# Duration                   0
# Treatment_Effectiveness    0
# Adverse_Reactions          0
# Recovery_Time_Days         0
# dtype: int64

# %%
df3.plot.box()
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler, LabelEncoder
# import pandas as pd
# col=[['Gender','Chronic_Conditions','Drug_Allergies','Genetic_Disorders','Diagnosis','Symptoms','Treatment_Effectiveness','Adverse_Reactions']]
# encoders=[]
# for colm in col:
#     le=LabelEncoder()
#     r2[col]= le.fit_transform(r2[col].astype(str))
#     encoders.append(le)

label_encoders = {}
categorical_columns = ['Patient_ID','Gender','Chronic_Conditions','Drug_Allergies','Genetic_Disorders','Symptoms','Treatment_Effectiveness','Adverse_Reactions']

for col in categorical_columns:
    le = LabelEncoder()
    df3[col] = le.fit_transform(df3[col])
    label_encoders[col] = le

# from sklearn.preprocessing import OneHotEncoder
# import pandas as pd

# categorical_columns = ['Patient_ID','Gender','Chronic_Conditions','Drug_Allergies','Genetic_Disorders','Symptoms','Treatment_Effectiveness','Adverse_Reactions']

# # 1. Initialize OneHotEncoder
# # sparse_output=False makes it easier to merge back into a DataFrame
# encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')

# # 2. Fit and transform the selected columns
# encoded_data = encoder.fit_transform(df3[categorical_columns])

# # 3. Create a new DataFrame with proper column names
# encoded_df3 = pd.DataFrame(encoded_data, columns=encoder.get_feature_names_out(categorical_columns))

# # 4. Concatenate with original data (dropping old categorical columns)
# df3 = pd.concat([df3.drop(columns=categorical_columns), encoded_df3], axis=1)
    


# cols_to_encode = ['Gender','Chronic_Conditions','Drug_Allergies','Genetic_Disorders','Diagnosis','Symptoms','Treatment_Effectiveness','Adverse_Reactions']

# # Apply encoding
# df3_final = pd.get_dummies(df3, columns=cols_to_encode, drop_first=True, dtype=int)











# from sklearn.preprocessing import LabelEncoder
# le = LabelEncoder()
# for col in r2.columns:
#     r2 = r2.apply(LabelEncoder().fit_transform)


# from sklearn.preprocessing import OrdinalEncoder
# encoder = OrdinalEncoder()
# df3_encoded = encoder.fit_transform(df3)

# %%
from sklearn.preprocessing import LabelEncoder
colm='Diagnosis'
encoder=LabelEncoder()
df3[colm]=encoder.fit_transform(df3[colm])

# %%
df3
# Out:
#      Patient_ID  Age  Gender  Weight_kg  Height_cm   BMI  Chronic_Conditions  \
# 0             0   78       2       88.7      196.3  21.1                   2
# 1             1   57       0       90.5      195.6  30.2                   2
# 2             2   29       0       87.0      168.2  27.0                   2
# 3             3   56       0       81.4      188.9  26.9                   2
# 4             4   90       1       64.2      157.0  33.3                   2
# ..          ...  ...     ...        ...        ...   ...                 ...
# 995         995   37       1       99.1      159.2  26.8                   1
# 996         996   28       2      102.8      178.7  34.1                   0
# 997         997   67       1       58.1      198.1  20.4                   0
# 998         998   79       1       51.1      171.9  25.8                   2
# 999         999   70       2       62.4      199.8  25.4                   0
#
# ...

# %%
x=df3[['Age','Weight_kg','Symptoms','Diagnosis','Genetic_Disorders']]
y=df3[['Recommended_Medication']]

x
# Out:
#      Age  Weight_kg  Symptoms  Diagnosis  Genetic_Disorders
# 0     78       88.7        90          4                  0
# 1     57       90.5        77          1                  0
# 2     29       87.0       178          4                  0
# 3     56       81.4       152          3                  0
# 4     90       64.2        72          4                  1
# ..   ...        ...       ...        ...                ...
# 995   37       99.1       121          1                  1
# 996   28      102.8       175          1                  0
# 997   67       58.1         1          2                  0
# 998   79       51.1        70          0                  0
# 999   70       62.4        91          4                  0
#
# [1000 rows x 5 columns]

# %%
y
# Out:
#     Recommended_Medication
# 0               Amlodipine
# 1              Amoxicillin
# 2              Amoxicillin
# 3                Ibuprofen
# 4               Amlodipine
# ..                     ...
# 995             Amlodipine
# 996             Amlodipine
# 997              Ibuprofen
# 998              Ibuprofen
# 999            Amoxicillin
#
# [1000 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=10)

y_test
# Out:
#     Recommended_Medication
# 841              Ibuprofen
# 956            Amoxicillin
# 544              Ibuprofen
# 173              Ibuprofen
# 759              Ibuprofen
# ..                     ...
# 181             Amlodipine
# 1              Amoxicillin
# 861              Ibuprofen
# 304            Amoxicillin
# 569              Ibuprofen
#
# [100 rows x 1 columns]

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=1, metric='euclidean')

knn.fit(x_train,y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:239: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier(metric='euclidean', n_neighbors=1)

# %%
pred=knn.predict(x_test)
pred
# Out:
# array(['Ibuprofen', 'Amlodipine', 'Ibuprofen', 'Amlodipine', 'Amlodipine',
#        'Amlodipine', 'Amoxicillin', 'Amlodipine', 'Amlodipine',
#        'Amoxicillin', 'Ibuprofen', 'Amoxicillin', 'Ibuprofen',
#        'Amlodipine', 'Amoxicillin', 'Amoxicillin', 'Amlodipine',
#        'Amoxicillin', 'Amoxicillin', 'Amlodipine', 'Amoxicillin',
#        'Amlodipine', 'Amlodipine', 'Amoxicillin', 'Amoxicillin',
#        'Ibuprofen', 'Ibuprofen', 'Amlodipine', 'Amoxicillin',
#        'Amoxicillin', 'Amlodipine', 'Ibuprofen', 'Amlodipine',
#        'Ibuprofen', 'Ibuprofen', 'Amoxicillin', 'Ibuprofen', 'Ibuprofen',
#        'Amoxicillin', 'Amoxicillin', 'Amlodipine', 'Amlodipine',
#        'Ibuprofen', 'Amlodipine', 'Amoxicillin', 'Amlodipine',
#        'Ibuprofen', 'Ibuprofen', 'Ibuprofen', 'Amlodipine', 'Ibuprofen',
#        'Ibuprofen', 'Ibuprofen', 'Ibuprofen', 'Amlodipine', 'Ibuprofen',
#        'Ibuprofen', 'Ibuprofen', 'Amlodipine', 'Ibuprofen', 'Amoxicillin',
# ...

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

results=confusion_matrix(y_test,pred)
print('confusion matrix')
print(results)
print('Accuracy score:', accuracy_score(y_test, pred))
print(classification_report(y_test, pred))
# Out:
# confusion matrix
# [[19  9 11]
#  [ 7 21  8]
#  [ 7  5 13]]
# Accuracy score: 0.53
#               precision    recall  f1-score   support
#
#   Amlodipine       0.58      0.49      0.53        39
#  Amoxicillin       0.60      0.58      0.59        36
#    Ibuprofen       0.41      0.52      0.46        25
#
#     accuracy                           0.53       100
#    macro avg       0.53      0.53      0.53       100
# weighted avg       0.54      0.53      0.53       100

# %%
import numpy as np

# %%
k1=np.array([[90,64.2,72,4,1]])
k1
# Out:
# array([[90. , 64.2, 72. ,  4. ,  1. ]])

# %%
pred=knn.predict(k1)
pred
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array(['Amlodipine'], dtype=object)

# %%
k2=np.array([[79,	51.1,	70,	0,	0]])
k2
# Out:
# array([[79. , 51.1, 70. ,  0. ,  0. ]])

# %%
pred=knn.predict(k2)
pred
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array(['Ibuprofen'], dtype=object)
