# %%
conda install beautifulsoup4
# Out:
# Jupyter detected...
# 3 channel Terms of Service accepted
# Retrieving notices: done
# Channels:
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\anaconda3
#
#   added / updated specs:
#     - beautifulsoup4
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     beautifulsoup4-4.14.3      |  py313haa95532_0         252 KB
#     ------------------------------------------------------------
#                                            Total:         252 KB
#
# The following packages will be UPDATED:
#
#   beautifulsoup4                     4.12.3-py313haa95532_0 --> 4.14.3-py313haa95532_0
#
#
#
# Downloading and Extracting Packages: ...working...
# beautifulsoup4-4.14. | 252 KB    |            |   0%
# beautifulsoup4-4.14. | 252 KB    | 6          |   6%
# beautifulsoup4-4.14. | 252 KB    | #####7     |  57%
# beautifulsoup4-4.14. | 252 KB    | ########9  |  89%
# beautifulsoup4-4.14. | 252 KB    | ########## | 100%
# beautifulsoup4-4.14. | 252 KB    | ########## | 100%
#
#  done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.5.1
#     latest version: 26.5.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
pip install tk
# Out:
# Requirement already satisfied: tk in .\AppData\Roaming\Python\Python313\site-packages (0.1.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pytesseract pillow
# Out:
# Requirement already satisfied: pytesseract in .\AppData\Roaming\Python\Python313\site-packages (0.3.13)
# Requirement already satisfied: pillow in .\AppData\Roaming\Python\Python313\site-packages (12.2.0)
# Requirement already satisfied: packaging>=21.3 in .\AppData\Roaming\Python\Python313\site-packages (from pytesseract) (26.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import tkinter as tk
from tkinter import *
import pyttsx3
import speech_recognition as sr
from googletrans import Translator
from tkinter.ttk import Combobox # dropdown list
from tkinter import Label as label, Button as combo
import urllib.request
from bs4 import BeautifulSoup  #Beautiful Soup is a Python library for pulling data out of HTML and XML files(XML: eXtensible Markup Language)
from PIL import Image
import pytesseract # It is a wrapper, a Python tool that allows your computer to "read" text inside images


t = tk.Tk() 
t.geometry("1350x750+0+0")
t.title("Translator")
t.config(bg="Turquoise")
def translator():
    if combo.get()=="hindi":

        result=textvalue.get()
        p=Translator()
        k=p.translate(result, dest="hi")
        l=k.text

        s.set(l)
        engine=pyttsx3.init()
        engine.say(l)
        engine.runAndWait()

    elif combo.get()=="english":
        result=textvalue.get()
        p=Translator()
        k=p.translate(result, dest="en")
        l=k.text

        s.set(l)
        engine=pyttsx3.init()
        engine.say(l)
        engine.runAndWait()

    elif combo.get()=="urdu":
        result=textvalue.get()
        p=Translator()
        k=p.translate(result, dest="ur")
        l=k.text

        s.set(l)
        engine=pyttsx3.init()
        engine.say(l)
        engine.runAndWait()

    elif combo.get()=="france":
        result=textvalue.get()
        p=Translator()
        k=p.translate(result, dest="fr")
        l=k.text

        s.set(l)
        engine=pyttsx3.init()
        engine.say(l)
        engine.runAndWait()

    elif combo1.get()=="france":
        result=textvalue.get()
        p=Translator()
        k=p.translate(result, dest="fr")
        l=k.text

        s.set(l)
        engine=pyttsx3.init()
        engine.say(l)
        engine.runAndWait()

    elif combo1.get()=="english":
        result=textvalue.get()
        p=Translator()
        k=p.translate(result, dest="en")
        l=k.text

        s.set(l)
        engine=pyttsx3.init()
        engine.say(l)
        engine.runAndWait()

    elif combo.get()=="italian":
        result=textvalue.get()
        p=Translator()
        k=p.translate(result, dest="it")
        l=k.text

        s.set(l)
        engine=pyttsx3.init()
        engine.say(l)
        engine.runAndWait()

    elif combo1.get()=="italian":
        result=textvalue.get()
        p=Translator()
        k=p.translate(result, dest="it")
        l=k.text

        s.set(l)
        engine=pyttsx3.init()
        engine.say(l)
        engine.runAndWait()

    else:
        notification.set("First select the Language")


def speak():
    r=sr.Recognizer()
    with sr.Microphone()as source:
        print("Say Something")
        notification.set("say something")
        audio=r.listen(source,0,5)
        print("Done")
        notification.set("Done")
    text=r.recognize_google(audio)
    textvalue.set(text)

    
    


def searching():
    if option.get()=="Browser link":

        response=urllib.request.urlopen(browser.get())
        h=response.read()
        soup=BeautifulSoup(h, "html5lib")
        text=soup.get_text(strip=False)
        print(text)
        textvalue.set(text)

    elif option.get()=="Image Link":
        img=Image.open(browser.get())
        notification.set(img)
        pytesseract.pytesseract.tesseract_cmd="C:\Program Files\Tesseract-OCR\tesseract.exe"
        result=pytesseract.image_to_string(img)
        textvalue.set(result)
        




v=['blank', 'hindi', 'english', 'france', 'urdu', 'italian']
combo=Combobox(t, values=v, width=35)
combo.set("select language")
combo.place(x=300, y=160)
combo1=Combobox(t, values=v, width=35)
combo.set("select language")
combo.place(x=900, y=160)
label(t, text="VIET", font="Ebrima 50 bold").place(x=590, y=0)
label(t, text="TRANSLATOR", font="Ebrima 10 bold").place(x=620, y=80)
        
text=Label(t, text="Enter", font="Ebrima 20 bold").place(x=200, y=250)

textvalue=StringVar()
textentry=Entry(t, textvariable=textvalue, font=50, width=30, bd=5).place(x=300, y=260)
s=StringVar()
notification=StringVar()
t=Entry(t, textvariable=s, font=20, width=30, bd=5).place(x=900, y=260)
trans=Button(t, text='Translate', command=translator, font="Ebrima 10 bold").place(x=700, y=360)
voice=Button(t, command=speak, text="VOICE", font="Ebrima 10 bold").place(x=600, y=360)
noti=Entry(t, textvariable=notification, bd=5, font="Ebrima 10 bold", width=40).place(x=510, y=400)


# BROWSER an IMAGE

Label(t, text='BROWSER AND IMAGE LINK', font="Ebrima 20 bold").place(x=100, y=450)
o=["Browser link", "Image link"]
option=Combobox(t, values=0, width=35)
option.set("select any one option")
option.place(x=100, y=500)
browser=StringVar()
brows=Entry(t, textvariable=browser, font='52', bd=5, width=50,).place(x=400, y=500)
search=Button(t, command=searching, bd=5, font="Ebrima 10 bold", text="search").place(x=900, y=498)


tk.mainloop()
