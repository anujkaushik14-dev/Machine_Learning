# %% [markdown]
# ## CROP_RECOMMENDATION_ANN_METHOD

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report, accuracy_score

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\vv\OneDrive\Desktop\PYTHON\DEEP LEARNING\Crop_recommendation.csv")
df
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
# pd.set_option("display.max_rows", None)

# %%
# pd.reset_option("display.max_rows")

# %%
df['label'].unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
# Encode Crop Labels
# --------------------------------------------------

from sklearn.preprocessing import LabelEncoder

# Initialize the encoder
le = LabelEncoder()

# Fit and transform the specific column
df['label'] = le.fit_transform(df['label'])

# # One-Hot Encoding
# y_categorical = to_categorical(y_encoded)

# %% [markdown]
# #### INPUT LAYER

# %%
x = df.drop("label", axis=1)
y = df.iloc[0:, 7:8]

# %%
x
# Out:
#         N   P   K  temperature   humidity        ph    rainfall
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340
# ...   ...  ..  ..          ...        ...       ...         ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041
#
# [2200 rows x 7 columns]

# %%
y
# Out:
#       label
# 0        20
# 1        20
# 2        20
# 3        20
# 4        20
# ...     ...
# 2195      5
# 2196      5
# 2197      5
# 2198      5
# 2199      5
#
# [2200 rows x 1 columns]

# %% [markdown]
# #### MODEL TRAIN

# %%
# Train-Test Split

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2,random_state=42)

# %% [markdown]
# #### feature scaling

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train_sc=sc.fit_transform(x_train)
x_test_sc=sc.transform(x_test)

# %% [markdown]
# ##### BUILD ANN MODEL AND HIDDEN LAYER(H1)

# %%
# Build ANN Model and HIDDEN layers
# Index 0 (train_sc.shape[0]): Represents the total number of rows (sample size).
# Index 1 (train_sc.shape[1]): Represents the total number of columns (features or variables).

classifier = Sequential()

classifier.add(Dense(units=64, activation='relu',input_shape=(x_train_sc.shape[1],)))
classifier.add(Dropout(0.3))
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# #### H2

# %%
classifier.add(Dense(units=64, activation='relu'))
classifier.add(Dropout(0.3))

# %% [markdown]
# #### H3

# %%
classifier.add(Dense(units=32, activation='relu'))

# %% [markdown]
# #### ACTIVATION FUNCTION: SOFTMAX for MULTI-CATEGORY

# %%
classifier.add(Dense(units=22,activation='softmax'))

# %% [markdown]
# #### OUTPUT LAYER

# %%
# Compile Model

classifier.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
# Train Model

classifier.fit(x_train_sc, y_train, batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1688 - loss: 2.8635
# Epoch 2/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3261 - loss: 2.2177
# Epoch 3/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4949 - loss: 1.5300
# Epoch 4/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6369 - loss: 1.1005
# Epoch 5/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6875 - loss: 0.8827
# Epoch 6/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7267 - loss: 0.7518
# Epoch 7/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7534 - loss: 0.6667
# Epoch 8/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7875 - loss: 0.5735
# Epoch 9/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8062 - loss: 0.5184
# Epoch 10/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8148 - loss: 0.4883
# Epoch 11/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8278 - loss: 0.4737
# Epoch 12/100
# ...

# %%
Dense(len(le.classes_), activation="softmax")
# Out:
# <Dense name=dense_9, built=False>

# %%
# # Evaluate Model
# # In programming and machine learning, verbose = 0 means "silent mode.
# # "It tells a computer program or script to run quietly in the background without displaying any extra text, status bars, or logs on your screen
# # How Verbose Levels Usually Work
# # Think of the verbose setting like the volume knob for how much the computer should talk back to you:
# # verbose = 0 (Silent): The computer shows nothing. It only gives you the final result at the very end.
# # verbose = 1 (Basic): The computer shows standard updates, like a progress bar or a quick loading percentage so you know it hasn't crashed.
# # verbose = 2 (Detailed): The computer lists step-by-step updates for every action (e.g., each training cycle or "epoch")

# loss, accuracy = classifier.evaluate(x_test,y_test,verbose=0)

# %%
# Since the output is a set of probabilities that sum to 1.0 (if using Softmax), 
# you need to find the index of the highest value. This index corresponds to the crop the model "thinks" is the best fit for the given soil and 
# weather parameters.
# Math Logic: Predicted_Class = argmax(Output_Layer_Probabilities)



# Argmax (short for "argument of the maximum") is a function that tells you where the maximum value is, rather than what that value is.
# In machine learning, models often output a list of scores or probabilities for different categories (like "Cat," "Dog," or "Bird"). 
# While max would tell you the highest probability, argmax tells you which category that probability belongs to.

# %%
# [0] means: “Give me the first item from this array.”
# inverse_transform() → returns a list/array of labels
# even if there is only one label, it still comes as a list
# [0] is used to get the actual string

# %%
def recomand(a,b,c,d,e,f,g):
    input_data=np.array([[a,b,c,d,e,f,g]])
    scaled_input=sc.transform(input_data)
    pred=classifier.predict(scaled_input, verbose=True)
    pred_class_idx=np.argmax(pred)
    recomand_crop_name=le.inverse_transform([pred_class_idx])
    confidence=pred[0][pred_class_idx]*100
    return recomand_crop_name[0],confidence

# %%
sample_crop,sample_conf=recomand(104,	18,	30,	23.603016,	60.396475,	6.779833,	140.937041)
sample_crop, sample_conf
# Out:
# C:\Users\vv\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
